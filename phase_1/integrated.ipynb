# %%
# %run  letters_extraction.ipynb
# %run   preprocessing_file.ipynb 
# %run  count_rows.ipynb

# %%
img = cv2.imread("preprocessing_imgs/A3.png")
# img = img.astype(np.uint8)
cf.show_images([img,preprocessing(img, showTrace=False)])


img = count_rows(img)



img = cv2.imread("preprocessing_imgs/A3.png")
img = img.astype(np.uint8)
img = preprocessing(img, showTrace=False)
cf.show_images([img, preprocessing(img, showTrace=False)])


result2= count_rows(img)
for row in result2:
    # row= cv2.cvtColor(row, cv2.COLOR_BGR2GRAY)
    cf.show_images(get_letters(row, show_trace = True))
# Out:
# C:\Users\aatta\AppData\Local\Temp\ipykernel_27600\357006068.py:6: DeprecationWarning: Please use `rotate` from the `scipy.ndimage` namespace, the `scipy.ndimage.interpolation` namespace is deprecated.
#   data = inter.rotate(arr, angle, reshape=False, order=0)
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In [40], line 6
#       2 # img = img.astype(np.uint8)
#       3 cf.show_images([img,preprocessing(img, showTrace=False)])
# ----> 6 img = count_rows(img)
#      10 img = cv2.imread("preprocessing_imgs/A3.png")
#      11 img = img.astype(np.uint8)
#
# File ~\AppData\Local\Temp\ipykernel_27600\523357697.py:17, in count_rows(image)
#      13 dilated = cv2.dilate(inverted_image,kernel=se)
#      14 cf.io.imshow(dilated)
# ---> 17 contours, _ = cv2.findContours(dilated, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)
#      18 contours = list(filter(lambda cnt: cv2.contourArea(cnt,True) < 0 , contours))
#      19 contours_list = [(x,y,w,h) for x,y,w,h in [cv2.boundingRect(c) for c in contours]]
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\contours.cpp:197: error: (-210:Unsupported format or combination of formats) [Start]FindContours supports only CV_8UC1 images when mode != CV_RETR_FLOODFILL otherwise supports CV_32SC1 images only in function 'cvStartFindContours_Impl'
